# %% [markdown]
# # Import librairies

# %%
import pandas as pd
import sys
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append("../utile")
from utile import plot_text_feature,plot_continous_feature

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("../data/escp_training_set.csv")

# %%
features_to_plot = []

# %% [markdown]
# # Visualization of textual data

# %%
plot_text_feature(df, "industry", k=20, logY=True)
# Out:
# /appli/notebooks/../utile/utile.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels=keys, rotation=45, ha="right")

# %%
plot_text_feature(df, "sector", k=20, logY=True)
# Out:
# /appli/notebooks/../utile/utile.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels=keys, rotation=45, ha="right")

# %%
plot_text_feature(df, "country_name", k=20, logY=True)
# Out:
# /appli/notebooks/../utile/utile.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels=keys, rotation=45, ha="right")

# %% [markdown]
# # Continous features

# %%
# Set seaborn theme
sns.set_theme()

# Subplot
fig, ax = plt.subplots(1, 1)
fig.set_figheight(15)
fig.set_figwidth(25)
df["year_founded"].hist(bins=50)
#plot_continous_feature(df, "year_founded", k=20, Log=False)
# Out:
# <AxesSubplot:>

# %%
plot_continous_feature(df, "employees", k=20, Log=False, logx=False)

# %%
plot_continous_feature(df, "revenues", k=20, Log=False, logx=True)

# %%
plot_continous_feature(df, "market_cap", k=20, Log=False, logx=True)

# %%
df[df["year_founded"].isna()]
# Out:
#        company_id                 company_name  \
# 3             639                          104
# 6             827                          111
# 8            1217                 1414 Degrees
# 10           1421           180 Degree Capital
# 11           1434            180 Life Sciences
# ...           ...                          ...
# 25209     1519013  Zw Data Action Technologies
# 25211     1519025               Zwahlen & Mayr
# 25213     1519196        Zyf Lopsking Aluminum
# 25216     1519265      Zynerba Pharmaceuticals
# 25219     1519278                         Zynp
#
#                                      industry                  sector  \
# 3                     Staffing And Recruiting             Industrials
# 6                             Pharmaceuticals              Healthcare
# 8                                Oil & Energy               Utilities
# 10                           Asset Management      Financial Services
# ...

# %%
df.columns
# Out:
# Index(['company_id', 'company_name', 'industry', 'sector', 'website',
#        'year_founded', 'employees', 'city', 'country_name', 'revenues',
#        'title', 'description', 'insta', 'twitter', 'fb', 'linkedin',
#        'description_twitter', 'audience', 'market_cap'],
#       dtype='object')

# %%
df[df["title"].isna()]
# Out:
#        company_id                    company_name  \
# 66           8042              5I5J Holding Group
# 101         11884          A & S Group (Holdings)
# 129         14670            Ab Fagerhult (Publ.)
# 155         15790     Abby - abbyholdinggroup.com
# 183         17194              Ability Enterprise
# ...           ...                             ...
# 25158     1516580                    Ziprecruiter
# 25162     1516931  Zmfy Automobile Glass Services
# 25200     1518751                  Zumtobel Group
# 25204     1518860          Zurich Insurance Group
# 25212     1519187              Zydus Lifesciences
#
#                                   industry                  sector  \
# 66                                  Retail       Consumer Cyclical
# 101                      Import And Export             Industrials
# 129    Electrical/Electronic Manufacturing             Industrials
# 155                               Internet  Communication Services
# ...

# %%
df["title"]
# Out:
# 0                   Post-Quantum Cybersecurity : 01com.com
# 1        Flowers | Flower Delivery | Fresh Flowers Onli...
# 2                                       Accueil | Numberly
# 3                                          corp.104.com.tw
# 4                                 Home Page - 10x Genomics
#                                ...
# 25216                                       Home - Zynerba
# 25217    Zynex Medical – Prescription TENS device, IFC,...
# 25218                           Free Mobile & Online Games
# 25219    Qi Gang Tao |Huo Sai Huan |Zhou Wa |Si Zu Jian...
# 25220                        Touch Screen Manufacturers UK
# Name: title, Length: 25221, dtype: object
