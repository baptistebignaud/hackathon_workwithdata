# %% [markdown]
# # Import librairies

# %%
import pandas as pd
import sys
sys.path.append("../utile")
from utile import plot_text_feature,plot_continous_feature

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("../escp_training_set.csv")

# %%
features_to_plot = []

# %% [markdown]
# # Visualization of textual data

# %%
plot_text_feature(df, "industry", k=20, logY=True)
# Out:
# /appli/notebooks/../utile/utile.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(labels=keys, rotation=45, ha="right")

# %%
df.head()
# Out:
#    company_id              company_name                   industry  \
# 0          28  01 Communique Laboratory          Computer Software
# 1         190         1-800-Flowers.Com                     Retail
# 2         522                1000Mercis  Marketing And Advertising
# 3         639                       104    Staffing And Recruiting
# 4         763              10X Genomics              Biotechnology
#
#                    sector                      website  year_founded  \
# 0              Technology        https://www.01com.com        1992.0
# 1       Consumer Cyclical  https://www.1800flowers.com        1976.0
# 2  Communication Services         https://numberly.com        2000.0
# 3             Industrials      https://corp.104.com.tw           NaN
# 4              Healthcare  https://www.10xgenomics.com        2016.0
#
#    employees             city   country_name      revenues  \
# 0        125          Toronto         Canada  7.091890e+05
# 1       4800          Jericho  United States  2.147850e+09
# 2        386            Paris         France  7.195000e+07
# 3         14  New Taipei City         Taiwan  6.033820e+07
# 4       1148       Pleasanton  United States  4.591780e+08
#
#                                                title  \
# 0             Post-Quantum Cybersecurity : 01com.com
# 1  Flowers | Flower Delivery | Fresh Flowers Onli...
# 2                                 Accueil | Numberly
# 3                                    corp.104.com.tw
# 4                           Home Page - 10x Genomics
#
#                                          description  \
# 0                                                NaN
# 1  Send flowers and send a smile! Discover fresh ...
# 2                                                NaN
# 3                                                NaN
# 4          Resolving Biology to Advance Human Health
#
#                                    insta                          twitter  \
# 0                                    NaN                              NaN
# 1  https://www.instagram.com/1800flowers  https://twitter.com/1800flowers
# 2                                    NaN     https://twitter.com/Numberly
# 3                                    NaN                              NaN
# 4                                    NaN  https://twitter.com/10xGenomics
#
#                                              fb  \
# 0                                           NaN
# 1          https://www.facebook.com/1800flowers
# 2  https://www.facebook.com/Numberly1000mercis/
# 3                                           NaN
# 4         https://www.facebook.com/10xGenomics/
#
#                                linkedin  \
# 0    linkedin.com/company/01-communique
# 1  linkedin.com/company/1800flowers-com
# 2       linkedin.com/company/1000mercis
# 3                                   NaN
# 4         linkedin.com/company/readcoor
#
#                                  description_twitter   audience    market_cap
# 0                                                NaN        NaN  1.797640e+07
# 1                                                NaN   624395.0  1.837320e+09
# 2  Marketing Technologist — Omnichannel. Programm...    22773.1  5.283550e+07
# 3                                                NaN        NaN  2.174950e+08
# 4  Powering researchers’ insights with innovative...  1583000.0  7.873110e+09
